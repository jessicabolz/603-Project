# %% [markdown]
# ###Part I:  Introduction

# %% [markdown]
# ####Group 4 members:
# #####Jessica Bolz
# #####Luis Galvan
# #####Nidhishree Sanam

# %% [markdown]
# ####Project:   Analyze data to build a predictive model for closing price of a stock  (can add more to this once we get into the data)

# %% [markdown]
# ###Part II:  Import necessary libraries and modules (import more here as needed throughout the project)

# %%
from pyspark.sql.types import *             
from pyspark.sql.functions import *
from pyspark.pandas.plot import *

# %% [markdown]
# ### Part III:  Read in the data sets and explore basic information for each

# %% [markdown]
# #####Dataset 1 is Telsa stock price from 2010 to 2017

# %%
#read in the Tesla data set, inferring the schema, and display

df1 = spark.read.format("csv").option("header", "true").load("dbfs:/FileStore/Tesla_csv___Tesla_csv.csv")
display(df1)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
df1.printSchema()
# Out:
# root
#  |-- Date: string (nullable = true)
#  |-- Open: string (nullable = true)
#  |-- High: string (nullable = true)
#  |-- Low: string (nullable = true)
#  |-- Close: string (nullable = true)
#  |-- Volume: string (nullable = true)
#  |-- Adj Close: string (nullable = true)

# %%
print("Number of rows: " ,df1.count())
print("Number of columns: ", len(df1.columns))
# Out:
# Number of rows:  1692
# Number of columns:  7

# %%
df1.describe().show(vertical=True)
# Out:
# -RECORD 0-----------------------
#  summary   | count
#  Date      | 1692
#  Open      | 1692
#  High      | 1692
#  Low       | 1692
#  Close     | 1692
#  Volume    | 1692
#  Adj Close | 1692
# -RECORD 1-----------------------
#  summary   | mean
#  Date      | null
#  Open      | 132.44157213711588
#  High      | 134.76969843853428
#  Low       | 129.99622341843985
#  Close     | 132.42865848581542
#  Volume    | 4270740.898345154
#  Adj Close | 132.42865848581542
# -RECORD 2-----------------------
#  summary   | stddev
#  Date      | null
#  Open      | 94.30992332283287
#  High      | 95.69491432029608
#  Low       | 92.85522729476058
#  Close     | 94.31318671731373
#  Volume    | 4295971.345667599
#  Adj Close | 94.31318671731373
# -RECORD 3-----------------------
#  summary   | min
#  Date      | 1/10/2011
#  Open      | 100
#  High      | 100.480003
#  Low       | 100.300003
#  Close     | 100.050003
#  Volume    | 1001600
#  Adj Close | 100.050003
# ...

# %% [markdown]
# #####Dataset 2 is Apple's (AAPL) stock data for ten years from 2010 to 2020.

# %%
#read in the Apple historical data set, inferring the schema, and display

df2 = spark.read.format("csv").option("header", "true").load("dbfs:/FileStore/HistoricalQuotes.csv")
display(df2)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
df2.printSchema()
# Out:
# root
#  |-- Date: string (nullable = true)
#  |--  Close/Last: string (nullable = true)
#  |--  Volume: string (nullable = true)
#  |--  Open: string (nullable = true)
#  |--  High: string (nullable = true)
#  |--  Low: string (nullable = true)

# %%
print("Number of rows: " ,df2.count())
print("Number of columns: ", len(df2.columns))
# Out:
# Number of rows:  2518
# Number of columns:  6

# %%
df2.describe().show(vertical=True)   #this isn't working; we need to clean/change to integer or get rid of $
# Out:
# -RECORD 0---------------------------
#  summary     | count
#  Date        | 2518
#   Close/Last | 2518
#   Volume     | 2518
#   Open       | 2518
#   High       | 2518
#   Low        | 2518
# -RECORD 1---------------------------
#  summary     | mean
#  Date        | null
#   Close/Last | null
#   Volume     | 7.258009426211278E7
#   Open       | null
#   High       | null
#   Low        | null
# -RECORD 2---------------------------
#  summary     | stddev
#  Date        | null
#   Close/Last | null
#   Volume     | 5.6631126108815454E7
#   Open       | null
#   High       | null
#   Low        | null
# -RECORD 3---------------------------
#  summary     | min
#  Date        | 01/02/2013
#   Close/Last |  $100.0135
#   Volume     |  100135800
#   Open       |  $100
#   High       |  $100
#   Low        |  $100.11
# -RECORD 4---------------------------
#  summary     | max
#  Date        | 12/31/2019
#   Close/Last |  $99.99
#   Volume     |  99957720
#   Open       |  $99.9828
# ...

# %% [markdown]
# #####Dataset 3 is the historical stock prices for 5 years from 2013 to 2018 for all companies currently found on the S&P 500 index.

# %%
#read in the S&P 500 stock data set, inferring the schema, and display

df3 = spark.read.format("csv").option("header", "true").load("dbfs:/FileStore/all_stocks_5yr.csv")
display(df3)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
df3.printSchema()
# Out:
# root
#  |-- date: string (nullable = true)
#  |-- open: string (nullable = true)
#  |-- high: string (nullable = true)
#  |-- low: string (nullable = true)
#  |-- close: string (nullable = true)
#  |-- volume: string (nullable = true)
#  |-- Name: string (nullable = true)

# %%
print("Number of rows: " ,df3.count())
print("Number of columns: ", len(df3.columns))
# Out:
# Number of rows:  619040
# Number of columns:  7

# %%
df3.describe().show(vertical=True)
# Out:
# -RECORD 0--------------------
#  summary | count
#  date    | 619040
#  open    | 619029
#  high    | 619032
#  low     | 619032
#  close   | 619040
#  volume  | 619040
#  Name    | 619040
# -RECORD 1--------------------
#  summary | mean
#  date    | null
#  open    | 83.0233343145474
#  high    | 83.77831069347276
#  low     | 82.25609641375338
#  close   | 83.04376276476519
#  volume  | 4321823.395568945
#  Name    | null
# -RECORD 2--------------------
#  summary | stddev
#  date    | null
#  open    | 97.3787690433237
#  high    | 98.20751890446375
#  low     | 96.50742105809033
#  close   | 97.38974800165782
#  volume  | 8693609.511967566
#  Name    | null
# -RECORD 3--------------------
#  summary | min
#  date    | 2013-02-08
#  open    | 1.62
#  high    | 1.69
#  low     | 1.5
#  close   | 1.59
#  volume  | 0
#  Name    | A
# -RECORD 4--------------------
#  summary | max
#  date    | 2018-02-07
#  open    | 999.47
#  high    | 999.75
#  low     | 999.48
#  close   | 999.6
# ...

# %% [markdown]
# #####Dataset 4 is historical price information for 3 high growth stocks and bitcoin from May 2013 to May 2019.

# %%
#read in the Amazon, Dominos, BitCoin, and Netflix stock data set, inferring the schema, and display

df4 = spark.read.format("csv").option("header", "true").load("dbfs:/FileStore/portfolio_data.csv")
display(df4)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
df4.printSchema()
# Out:
# root
#  |-- Date: string (nullable = true)
#  |-- AMZN: string (nullable = true)
#  |-- DPZ: string (nullable = true)
#  |-- BTC: string (nullable = true)
#  |-- NFLX: string (nullable = true)

# %%
print("Number of rows: " ,df4.count())
print("Number of columns: ", len(df4.columns))
# Out:
# Number of rows:  1520
# Number of columns:  5

# %%
df4.describe().show(vertical=True)
# Out:
# -RECORD 0---------------------
#  summary | count
#  Date    | 1520
#  AMZN    | 1520
#  DPZ     | 1520
#  BTC     | 1520
#  NFLX    | 1520
# -RECORD 1---------------------
#  summary | mean
#  Date    | null
#  AMZN    | 821.5418097875003
#  DPZ     | 146.7716948388157
#  BTC     | 2421.465668559871
#  NFLX    | 147.66827257960543
# -RECORD 2---------------------
#  summary | stddev
#  Date    | null
#  AMZN    | 518.4426534119234
#  DPZ     | 72.19228694375188
#  BTC     | 3310.8941990967246
#  NFLX    | 107.64148632525637
# -RECORD 3---------------------
#  summary | min
#  Date    | 1/10/2014
#  AMZN    | 1000.630005
#  DPZ     | 100.01207
#  BTC     | 100
#  NFLX    | 100.040001
# -RECORD 4---------------------
#  summary | max
#  Date    | 9/9/2016
#  AMZN    | 999.599976
#  DPZ     | 99.989922
#  BTC     | 997.609985
#  NFLX    | 99.889999

# %% [markdown]
# ###Part IV:  Visualize the data
